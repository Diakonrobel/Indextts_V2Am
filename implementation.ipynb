# %%
import pandas as pd
path = "german_sample_data/metadata.csv"

# %%
pd.read_csv(path, sep="|")
# Out:
#        0  caf01f7d6c6e6098f5367d7177133cdd  \
# 0      1  8ec26508fdc34143cfb1abdb43090721
# 1      2  b7f533ae2c2a726f1676613ed183163a
# 2      3  fd9338593b1a5ec176616b8ebbb90d2c
# 3      4  0455288e2a3ebf437da69991e7f470a6
# 4      5  b2be3f90bbc7633c8879e2d7890175ab
# ..   ...                               ...
# 994  995  bf9febf36f969c8889e099d4a7e49320
# 995  996  bea983b37e65f3f93349441cc48ea926
# 996  997  5d5a8f0a60a0c21353128526cddf8380
# 997  998  2aeb5da2dd2d5749916b0b1e37414c09
# 998  999  df45fd33df9f0f19278ed844bc0cdde8
#
#                                Was sollen wir nur tun?
# 0                               Darf ich die Fee sein?
# 1                                 Und welches Baujahr?
# 2                                             San Jose
# 3             Wer die lauteste Hupe hat, hat Vorfahrt.
# 4    Im Brutkasten ist es mollige siebenunddreißig ...
# ..                                                 ...
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# False
